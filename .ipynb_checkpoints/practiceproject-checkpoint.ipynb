# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# the code below removes the first column idk how to fix it right now.

# %%
trainDf = pd.read_csv("adult.data", skipinitialspace=True)
trainDf.columns = ["age" , "workclass", "fnlwgt", "education", "educationNum", "maritalStatus", "occupation", "relationship", "race", "sex", "capitalGain", "capitalLoss", "hoursPerWeek", "nativeCountry", "income"]
trainDf
# Out:
#        age         workclass  fnlwgt   education  educationNum  \
# 0       50  Self-emp-not-inc   83311   Bachelors            13
# 1       38           Private  215646     HS-grad             9
# 2       53           Private  234721        11th             7
# 3       28           Private  338409   Bachelors            13
# 4       37           Private  284582     Masters            14
# ...    ...               ...     ...         ...           ...
# 32555   27           Private  257302  Assoc-acdm            12
# 32556   40           Private  154374     HS-grad             9
# 32557   58           Private  151910     HS-grad             9
# 32558   22           Private  201490     HS-grad             9
# 32559   52      Self-emp-inc  287927     HS-grad             9
#
#             maritalStatus         occupation   relationship   race     sex  \
# 0      Married-civ-spouse    Exec-managerial        Husband  White    Male
# ...

# %%
testDf = pd.read_csv("adult.test", skipinitialspace=True)
testDf.columns = ["age" , "workclass", "fnlwgt", "education", "educationNum", "maritalStatus", "occupation", "relationship", "race", "sex", "capitalGain", "capitalLoss", "hoursPerWeek", "nativeCountry", "income"]
testDf["income"] = testDf["income"].str.replace('.', '')
testDf
# Out:
# <ipython-input-3-5335d5a4671d>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   testDf["income"] = testDf["income"].str.replace('.', '')
#        age     workclass  fnlwgt     education  educationNum  \
# 0       38       Private   89814       HS-grad             9
# 1       28     Local-gov  336951    Assoc-acdm            12
# 2       44       Private  160323  Some-college            10
# 3       18             ?  103497  Some-college            10
# 4       34       Private  198693          10th             6
# ...    ...           ...     ...           ...           ...
# 16275   39       Private  215419     Bachelors            13
# 16276   64             ?  321403       HS-grad             9
# 16277   38       Private  374983     Bachelors            13
# 16278   44       Private   83891     Bachelors            13
# ...

# %%
print("train length = ", len(trainDf))
print("test len = ", len(testDf))
# Out:
# train length =  32560
# test len =  16280

# %% [markdown]
# removes rows that have '?'

# %%
trainDf = trainDf[(trainDf.values != '?').all(axis=1)]
testDf = testDf[(testDf.values != '?').all(axis=1)]
print("train length = ", len(trainDf))
print("test len = ", len(testDf))
# Out:
# train length =  30161
# test len =  15059

# %% [markdown]
# drops continous values

# %%
trainDf = trainDf.drop(["age" , "fnlwgt", "educationNum", "capitalGain", "capitalLoss", "hoursPerWeek"], axis=1)
trainDf
# Out:
#               workclass   education       maritalStatus         occupation  \
# 0      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 1               Private     HS-grad            Divorced  Handlers-cleaners
# 2               Private        11th  Married-civ-spouse  Handlers-cleaners
# 3               Private   Bachelors  Married-civ-spouse     Prof-specialty
# 4               Private     Masters  Married-civ-spouse    Exec-managerial
# ...                 ...         ...                 ...                ...
# 32555           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32556           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32557           Private     HS-grad             Widowed       Adm-clerical
# 32558           Private     HS-grad       Never-married       Adm-clerical
# 32559      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex  nativeCountry income
# ...

# %%
testDf = testDf.drop(["age" , "fnlwgt", "educationNum", "capitalGain", "capitalLoss", "hoursPerWeek"], axis=1)
testDf
# Out:
#               workclass     education       maritalStatus         occupation  \
# 0               Private       HS-grad  Married-civ-spouse    Farming-fishing
# 1             Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 2               Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4               Private          10th       Never-married      Other-service
# 6      Self-emp-not-inc   Prof-school  Married-civ-spouse     Prof-specialty
# ...                 ...           ...                 ...                ...
# 16274           Private     Bachelors       Never-married     Prof-specialty
# 16275           Private     Bachelors            Divorced     Prof-specialty
# 16277           Private     Bachelors  Married-civ-spouse     Prof-specialty
# 16278           Private     Bachelors            Divorced       Adm-clerical
# 16279      Self-emp-inc     Bachelors  Married-civ-spouse    Exec-managerial
#
# ...

# %% [markdown]
# converting the dataframes to csv's

# %%
trainDf.to_csv('train.csv')
testDf.to_csv('test.csv')

# %% [markdown]
# for some reason there is a column called unnamed:0

# %%
dfTrain = pd.read_csv("train.csv")
dfTrain.drop(["Unnamed: 0"],axis=1, inplace=True)
dfTrain
# Out:
#               workclass   education       maritalStatus         occupation  \
# 0      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 1               Private     HS-grad            Divorced  Handlers-cleaners
# 2               Private        11th  Married-civ-spouse  Handlers-cleaners
# 3               Private   Bachelors  Married-civ-spouse     Prof-specialty
# 4               Private     Masters  Married-civ-spouse    Exec-managerial
# ...                 ...         ...                 ...                ...
# 30156           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 30157           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 30158           Private     HS-grad             Widowed       Adm-clerical
# 30159           Private     HS-grad       Never-married       Adm-clerical
# 30160      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex  nativeCountry income
# ...

# %%
dfTest = pd.read_csv("test.csv")
dfTest.drop(["Unnamed: 0"],axis=1, inplace=True)
dfTest
# Out:
#               workclass     education       maritalStatus         occupation  \
# 0               Private       HS-grad  Married-civ-spouse    Farming-fishing
# 1             Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 2               Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 3               Private          10th       Never-married      Other-service
# 4      Self-emp-not-inc   Prof-school  Married-civ-spouse     Prof-specialty
# ...                 ...           ...                 ...                ...
# 15054           Private     Bachelors       Never-married     Prof-specialty
# 15055           Private     Bachelors            Divorced     Prof-specialty
# 15056           Private     Bachelors  Married-civ-spouse     Prof-specialty
# 15057           Private     Bachelors            Divorced       Adm-clerical
# 15058      Self-emp-inc     Bachelors  Married-civ-spouse    Exec-managerial
#
# ...

# %%
def oneHotBind(df, features):
    dummies = pd.get_dummies(df[features])
    res = pd.concat([df, dummies], axis=1)
    res = res.drop(features, axis=1)
    
    return res

# %%
dfTrain = oneHotBind(dfTrain, ["workclass", "education", "maritalStatus", "occupation", "relationship", "race", "sex", "nativeCountry", "income"])
dfTrain
# Out:
#        workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# 0                          0                    0                  0
# 1                          0                    0                  1
# 2                          0                    0                  1
# 3                          0                    0                  1
# 4                          0                    0                  1
# ...                      ...                  ...                ...
# 30156                      0                    0                  1
# 30157                      0                    0                  1
# 30158                      0                    0                  1
# 30159                      0                    0                  1
# 30160                      0                    0                  0
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 0                           0                           1
# ...

# %%
dfTest = oneHotBind(dfTest, ["workclass", "education", "maritalStatus", "occupation", "relationship", "race", "sex", "nativeCountry", "income"])
dfTest
# Out:
#        workclass_Federal-gov  workclass_Local-gov  workclass_Private  \
# 0                          0                    0                  1
# 1                          0                    1                  0
# 2                          0                    0                  1
# 3                          0                    0                  1
# 4                          0                    0                  0
# ...                      ...                  ...                ...
# 15054                      0                    0                  1
# 15055                      0                    0                  1
# 15056                      0                    0                  1
# 15057                      0                    0                  1
# 15058                      0                    0                  0
#
#        workclass_Self-emp-inc  workclass_Self-emp-not-inc  \
# 0                           0                           0
# ...

# %%
for attributes in dfTrain.keys():
    if attributes not in dfTest.keys():
        print("Adding missing feature {}".format(attributes))
        dfTest[attributes] = 0
# Out:
# Adding missing feature nativeCountry_Holand-Netherlands

# %%
features = []
target = []
for col in dfTrain.columns:
    if col == "income_<=50K" or col == 'income_>50K':
        target.append(col)
    else:
        features.append(col)

print(target)
print(features)
# Out:
# ['income_<=50K', 'income_>50K']
# ...

# %%
x = dfTrain[features]
y = dfTrain[target]
X = dfTest[features]
Y = dfTest[target]
# X_train, X_test, y_train, y_test = train_test_split(x,y)
tree = DecisionTreeClassifier()
tree.fit(x, y)
predictions = tree.predict(X)
print("Accuraccy: " + str(accuracy_score(Y, predictions)))
print(classification_report(Y, predictions))
# Out:
# Accuraccy: 0.7991898532439073
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87     11359
#            1       0.63      0.56      0.59      3700
#
#    micro avg       0.82      0.80      0.81     15059
#    macro avg       0.75      0.72      0.73     15059
# weighted avg       0.81      0.80      0.80     15059
#  samples avg       0.80      0.80      0.80     15059
# C:\Users\Yaling\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()
gnb.fit(x, y.iloc[:, 1:])
predictions = gnb.predict(X)

print('Accuracy: '+ str(accuracy_score(Y.iloc[:, 1:], predictions)))
print(classification_report(Y.iloc[:, 1:], predictions))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-c6c2e7cfd64e> in <module>
#       2
#       3 gnb = GaussianNB()
# ----> 4 gnb.fit(x, y[:, 1:])
#       5 predictions = gnb.predict(X)
#       6
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# ...
